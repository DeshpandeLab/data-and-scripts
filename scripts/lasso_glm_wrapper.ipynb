# %%
from ipynb.fs.full.lasso_model import lasso_reg
from ipynb.fs.full.glmnet_model import glmnet_lasso
import time

#wrapper function for the lasso regression functionality
#currently has sklearn lasso method implemented, could be replaced with glmnet method.

## input:
#y_index: Nx1 array, index/tag/name of y variables
#y_target: Nx1 matrix, target y variable in the regression
#X_design_matrix: NxM matrix, the design matrix containing all data, rows corresponding to index of y_index

## output:
#best alpha: the most optimal alpha (or lambda in some definitions) for the data
#alphas used for fitting: grid of all alphas used for fitting
#coef_predicted: Mx1 matrix, model coefficients, fitted values by the regression

def lasso_glm(y_index, y_target, X_design_matrix, lambda_value=0.3):
    
    start = time.time()
    #call function
    model = glmnet_lasso(y_index, y_target, X_design_matrix)
    
    end = time.time()
    elapsed = end-start
    
    print(reg)
    print(f'Time elapsed: {elapsed:.8f} seconds.')
# Out:
# /Users/emilyxie/anaconda3/envs/pyenv/lib/python3.6/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# /Users/emilyxie/anaconda3/envs/pyenv/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:532: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/emilyxie/anaconda3/envs/pyenv/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:532: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/emilyxie/anaconda3/envs/pyenv/lib/python3.6/site-packages/sklearn/linear_model/_coordinate_descent.py:532: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# ...

# %%
pip install ipynb
# Out:
# ...
#   Using cached ipynb-0.5.1-py3-none-any.whl (6.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/emilyxie/anaconda3/envs/pyenv/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/d6/dkzjd00j5d1247r7ct6cy2mc0000gn/T/pip-install-npjwsr27/sklearn_278d4e7af90645ac906f040103fda628/setup.py'"'"'; __file__='"'"'/private/var/folders/d6/dkzjd00j5d1247r7ct6cy2mc0000gn/T/pip-install-npjwsr27/sklearn_278d4e7af90645ac906f040103fda628/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/d6/dkzjd00j5d1247r7ct6cy2mc0000gn/T/pip-pip-egg-info-_dl9znhe
#        cwd: /private/var/folders/d6/dkzjd00j5d1247r7ct6cy2mc0000gn/T/pip-install-npjwsr27/sklearn_278d4e7af90645ac906f040103fda628/
# ...
